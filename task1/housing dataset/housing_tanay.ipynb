# %%
import pandas as pd

# %%
df = pd.read_csv('./train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# Visualizing missing values
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
# Histograms for numerical columns
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#selecting numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])
print(numerical_df.columns)
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = numerical_df.corr() #numerical_df is the numerical dataframe


# Display the correlation matrix
print(corr_matrix)

# Visualize the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
corr_matrix[corr_matrix > 0.5]
#print the pairs which have correlation greater than 0.5
print(corr_matrix[corr_matrix > 0.5])
# Visualizing the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix[corr_matrix > 0.5], annot=True, cmap='coolwarm')
plt.show()
#blue means positive correlation, red means negative correlation
# Out:
#                 Id  MSSubClass  LotFrontage  LotArea  OverallQual  \
# Id             1.0         NaN          NaN      NaN          NaN
# MSSubClass     NaN         1.0          NaN      NaN          NaN
# LotFrontage    NaN         NaN          1.0      NaN          NaN
# LotArea        NaN         NaN          NaN      1.0          NaN
# OverallQual    NaN         NaN          NaN      NaN     1.000000
# OverallCond    NaN         NaN          NaN      NaN          NaN
# YearBuilt      NaN         NaN          NaN      NaN     0.572323
# YearRemodAdd   NaN         NaN          NaN      NaN     0.550684
# MasVnrArea     NaN         NaN          NaN      NaN          NaN
# BsmtFinSF1     NaN         NaN          NaN      NaN          NaN
# BsmtFinSF2     NaN         NaN          NaN      NaN          NaN
# BsmtUnfSF      NaN         NaN          NaN      NaN          NaN
# TotalBsmtSF    NaN         NaN          NaN      NaN     0.537808
# ...

# %%
# Set a threshold
threshold = 0.7

# Iterate through the correlation matrix and print pairs with correlation > threshold
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > threshold: #abs means both positive and negative correlation
            print(f"Correlation between {corr_matrix.columns[i]} and {corr_matrix.columns[j]}: {corr_matrix.iloc[i, j]:.2f}")
# Out:
# Correlation between 1stFlrSF and TotalBsmtSF: 0.82
# Correlation between TotRmsAbvGrd and GrLivArea: 0.83
# Correlation between GarageYrBlt and YearBuilt: 0.83
# Correlation between GarageArea and GarageCars: 0.88
# Correlation between SalePrice and OverallQual: 0.79
# Correlation between SalePrice and GrLivArea: 0.71

# %%
# Set a threshold
threshold = -0.2

# Iterate through the correlation matrix and print pairs with correlation > threshold
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if (corr_matrix.iloc[i, j]) < threshold:
            print(f"Correlation between {corr_matrix.columns[i]} and {corr_matrix.columns[j]}: {corr_matrix.iloc[i, j]:.2f}")
# Out:
# Correlation between LotFrontage and MSSubClass: -0.39
# Correlation between YearBuilt and OverallCond: -0.38
# Correlation between BsmtUnfSF and BsmtFinSF1: -0.50
# Correlation between BsmtUnfSF and BsmtFinSF2: -0.21
# Correlation between TotalBsmtSF and MSSubClass: -0.24
# Correlation between 1stFlrSF and MSSubClass: -0.25
# Correlation between 2ndFlrSF and 1stFlrSF: -0.20
# Correlation between BsmtFullBath and BsmtUnfSF: -0.42
# Correlation between GarageYrBlt and OverallCond: -0.32
# Correlation between EnclosedPorch and YearBuilt: -0.39
# Correlation between EnclosedPorch and GarageYrBlt: -0.30

# %%
y = df['SalePrice']
print(y.describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#find the columns with a r value of 0.5 or higher with SalePrice
corr_matrix['SalePrice'][corr_matrix['SalePrice'] > 0.5]
# Out:
# OverallQual     0.790982
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# GrLivArea       0.708624
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# GarageCars      0.640409
# GarageArea      0.623431
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
y = df['SalePrice']
X = df[['OverallQual']]
print(X.head())
# Out:
#    OverallQual
# 0            7
# 1            6
# 2            7
# 3            7
# 4            8

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X)

# %%
#calculate rmse
from sklearn.metrics import mean_squared_error
import numpy as np
# Calculate the RMSE
rmse = np.sqrt(mean_squared_error(y, predictions))
print(rmse)
# Out:
# 48589.44712143806

# %%
#find the accuracy of the model
model.score(X, y)
# Out:
# 0.625651892462118

# %%
#prrint mean of sales price
print(y.mean())
# Out:
# 180921.19589041095

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
model = LinearRegression()

# %%
model.fit(X_scaled, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_scaled)

# %%
#find the accuracy of the model
model.score(X_scaled, y)
# Out:
# 0.6256518924621182

# %% [markdown]
# ### Now using more features

# %%
corr_matrix['SalePrice'][corr_matrix['SalePrice'] > 0.5]
# Out:
# OverallQual     0.790982
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# GrLivArea       0.708624
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# GarageCars      0.640409
# GarageArea      0.623431
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# As we can see, there are many other features that have high corr with sales Price.

# %%
X = df[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd']]    
X.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0            7       1710           2         548          856       856
# 1            6       1262           2         460         1262      1262
# 2            7       1786           2         608          920       920
# 3            7       1717           3         642          756       961
# 4            8       2198           3         836         1145      1145
#
#    FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd
# 0         2             8       2003          2003
# 1         2             6       1976          1976
# 2         2             6       2001          2002
# 3         1             7       1915          1970
# 4         2             9       2000          2000

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
#convert X_scaled to a dataframe
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
print(X_scaled.head())
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0     0.651479   0.370333    0.311725    0.351000    -0.459303 -0.793434
# 1    -0.071836  -0.482512    0.311725   -0.060731     0.466465  0.257140
# 2     0.651479   0.515013    0.311725    0.631726    -0.313369 -0.627826
# 3     0.651479   0.383659    1.650307    0.790804    -0.687324 -0.521734
# 4     1.374795   1.299326    1.650307    1.698485     0.199680 -0.045611
#
#    FullBath  TotRmsAbvGrd  YearBuilt  YearRemodAdd
# 0  0.789741      0.912210   1.050994      0.878668
# 1  0.789741     -0.318683   0.156734     -0.429577
# 2  0.789741     -0.318683   0.984752      0.830215
# 3 -1.026041      0.296763  -1.863632     -0.720298
# 4  0.789741      1.527656   0.951632      0.733308

# %%
model = LinearRegression()
y = df['SalePrice']
model.fit(X_scaled, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_scaled)

# %%
#check the accuracy of the model
model.score(X_scaled, y)
# Out:
# 0.7736928402773303

# %%
# test the accuracy of the model using test.csv
df_test = pd.read_csv('./test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#check accuracy of the model using numerical features of df_test
numerical_df_test = df_test.select_dtypes(include=['float64', 'int64'])
print(numerical_df_test.columns)
#now check the accuracy of the model using numerical_df_test
X_test = numerical_df_test[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd']]
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
print(X_test_scaled.head())
#predict the sale price
predictions = model.predict(X_test_scaled)
print(predictions)
#accuracy of the model
model.score(X_test_scaled, y)
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold'],
#       dtype='object')
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0    -0.795151  -1.179256   -1.026858    1.202536    -0.400017 -0.689929
# 1    -0.071836  -0.354966   -1.026858   -0.753188     0.619239  0.430511
# 2    -0.795151   0.216136    0.311725    0.042202    -0.295127 -0.607125
# 3    -0.071836   0.168544    0.311725   -0.013943    -0.299687 -0.612300
# ...
